# %%
# ngl works check

from nanover.nglview import NGLClient

# %%
import nglview as nv
nv.demo()

# %%
client = NGLClient.from_discovery(discovery_port=54545)
#client = NGLClient("ws://loclalhost:38801")

client.view
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 client = NGLClient.from_discovery(discovery_port=54545)
#       2 #client = NGLClient("ws://loclalhost:38801")
#       4 client.view
#
# File ~\Projects\Nanover\nanover-server-py\python-libraries\nanover-server\src\nanover\websocket\client\app_client.py:80, in NanoverImdClient.from_discovery(cls, server_name, discovery_port)
#      76     first_service = _search_for_first_local_server(
#      77         discovery_port=discovery_port
#      78     )
#      79     if first_service is None:
# ---> 80         raise ConnectionError("Couldn't discover server")
#      82 def get_url(protocol: str):
#      83     address = first_service.get_service_address(service_name=protocol)
#
# ConnectionError: Couldn't discover server

# %%
client.close
# Out:
# <bound method InteractionClient.close of <nanover.jupyter.nglclient.NGLClient object at 0x000001E1D0BACD10>>
